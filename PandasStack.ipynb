# %% [markdown]
# <a href="https://colab.research.google.com/github/therealfortune/DA-Portfolio-Project/blob/master/PandasStack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/survey_results_public.csv')
schema_df = pd.read_csv('/content/survey_results_schema.csv')

# %%
pd.set_option('display.max_rows', 85)
pd.set_option('display.max_columns', 85)

# %%
df.dtypes.head(3)
# Out:
# Respondent     int64
# MainBranch    object
# Hobbyist      object
# dtype: object

# %%
stud = (df['MainBranch'] == 'I am a student who is learning to code') & (df['Employment'] == 'Employed full-time')

# %%
df.loc[stud].head(3)
# Out:
#      Respondent                              MainBranch Hobbyist  \
# 139         141  I am a student who is learning to code      Yes
# 143         145  I am a student who is learning to code      Yes
# 500         502  I am a student who is learning to code      Yes
#
#                     OpenSourcer  \
# 139  Once a month or more often
# 143                       Never
# 500     Less than once per year
#
#                                             OpenSource          Employment  \
# 139  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 143  The quality of OSS and closed source software ...  Employed full-time
# 500  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#                 Country         Student  \
# 139         Netherlands  Yes, full-time
# 143               Japan  Yes, full-time
# 500  Russian Federation              No
#
#                                                EdLevel  \
# ...

# %%
Countries  = ['Nigeria']
filt = df['Country'].isin(Countries)
filt = df.loc[filt, ['Respondent','MainBranch','Hobbyist',	'OpenSourcer','Country']]
filt.head(3)
# Out:
#      Respondent                                         MainBranch Hobbyist  \
# 203         205  I am not primarily a developer, but I write co...      Yes
# 346         348                     I am a developer by profession      Yes
# 363         365                        I code primarily as a hobby      Yes
#
#                                            OpenSourcer  Country
# 203                            Less than once per year  Nigeria
# 346                            Less than once per year  Nigeria
# 363  Less than once a month but more than once per ...  Nigeria

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt, 'LanguageWorkedWith']
# Out:
# 0                         HTML/CSS;Java;JavaScript;Python
# 1                                     C++;HTML/CSS;Python
# 3                                     C;C++;C#;Python;SQL
# 4             C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7       Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                               ...
# 5645    HTML/CSS;Java;JavaScript;Objective-C;PHP;Pytho...
# 5655                HTML/CSS;JavaScript;Python;TypeScript
# 5662                    JavaScript;Python;Rust;TypeScript
# 5665                      HTML/CSS;Java;JavaScript;Python
# 5667        HTML/CSS;JavaScript;PHP;Python;SQL;TypeScript
# Name: LanguageWorkedWith, Length: 2403, dtype: object

# %%
df.rename(columns = {'ConvertedComp' : 'SalaryUSD'}, inplace=True)

# %%
HighSalary = df['SalaryUSD'] > 500000
HighSalary = df.loc[HighSalary, ['Respondent','MainBranch','Hobbyist','SalaryUSD']]
HighSalary.head()
# Out:
#      Respondent                                         MainBranch Hobbyist  \
# 31           32                     I am a developer by profession       No
# 57           58                     I am a developer by profession      Yes
# 101         102                     I am a developer by profession       No
# 127         128  I am not primarily a developer, but I write co...      Yes
# 153         155                     I am a developer by profession      Yes
#
#      SalaryUSD
# 31   1100000.0
# 57   2000000.0
# 101  2000000.0
# 127  1000000.0
# 153   962424.0

# %%
df['Hobbyist']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 5664     No
# 5665    Yes
# 5666    Yes
# 5667    Yes
# 5668     No
# Name: Hobbyist, Length: 5669, dtype: object

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes':True, 'No':False})

# %%
df.head(3)
# Out:
#    Respondent                                         MainBranch  Hobbyist  \
# 0           1             I am a student who is learning to code      True
# 1           2             I am a student who is learning to code     False
# 2           3  I am not primarily a developer, but I write co...      True
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
#
#           Student                                            EdLevel  \
# ...

# %%
df.sort_values(['Country','SalaryUSD'], ascending=[True, False]).head(5)
# Out:
#       Respondent                      MainBranch  Hobbyist  \
# 719          722  I am a developer by profession     False
# 3771        3787  I am a developer by profession      True
# 2324        2332  I am a developer by profession      True
# 1946        1954  I am a developer by profession     False
# 1536        1543  I am a developer by profession      True
#
#                                             OpenSourcer  \
# 719   Less than once a month but more than once per ...
# 3771                         Once a month or more often
# 2324                            Less than once per year
# 1946                                              Never
# 1536                            Less than once per year
#
#                                              OpenSource  \
# 719   The quality of OSS and closed source software ...
# 3771  OSS is, on average, of HIGHER quality than pro...
# 2324  OSS is, on average, of HIGHER quality than pro...
# ...

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# 57      2000000.0
# 101     2000000.0
# 164     2000000.0
# 434     2000000.0
# 450     2000000.0
# 489     2000000.0
# 537     2000000.0
# 767     2000000.0
# 786     2000000.0
# 1228    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10, 'SalaryUSD')
# Out:
#       Respondent                      MainBranch  Hobbyist  \
# 57            58  I am a developer by profession      True
# 101          102  I am a developer by profession     False
# 164          166  I am a developer by profession      True
# 434          436  I am a developer by profession      True
# 450          452  I am a developer by profession      True
# 489          491  I am a developer by profession      True
# 537          539  I am a developer by profession     False
# 767          770  I am a developer by profession      True
# 786          789  I am a developer by profession      True
# 1228        1232  I am a developer by profession     False
#
#                                             OpenSourcer  \
# 57                           Once a month or more often
# 101                                               Never
# 164                             Less than once per year
# 434                             Less than once per year
# ...
